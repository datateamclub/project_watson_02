# %% [markdown]
# # <font color='cornflowerblue'>Natural Language Inference Approach UM - Data Team Club

# %% [markdown]
# In the second UM Data Team Club project, we'll be diving into Natural Language Inference (NLI). Our goal is to explore and analyze the relationships between different text pairs to understand whether one sentence logically follows from another.

# %% [markdown]
# ## Contents Table
#  - [Imports](#1)
#  - [Accelerator](#2)
#  - [Load Data](#3)
#  - [Data Exploring](#4)
#  - [Data Preprocessing](#5)
#  - [BERT Base Multi Model](#6)

# %%
# !pip install keras_nlp
# !pip install seaborn
# !pip install wordcloud

# %% [markdown]
# ### Imports <a id='1'></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import seaborn as sns
sns.set_style('whitegrid')

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import keras_nlp
import os
# Out:
# D0912 22:57:31.352418502      15 config.cc:119]                        gRPC EXPERIMENT tcp_frame_size_tuning               OFF (default:OFF)
# D0912 22:57:31.352443873      15 config.cc:119]                        gRPC EXPERIMENT tcp_rcv_lowat                       OFF (default:OFF)
# D0912 22:57:31.352447505      15 config.cc:119]                        gRPC EXPERIMENT peer_state_based_framing            OFF (default:OFF)
# D0912 22:57:31.352450073      15 config.cc:119]                        gRPC EXPERIMENT flow_control_fixes                  ON  (default:ON)
# D0912 22:57:31.352452320      15 config.cc:119]                        gRPC EXPERIMENT memory_pressure_controller          OFF (default:OFF)
# D0912 22:57:31.352455003      15 config.cc:119]                        gRPC EXPERIMENT unconstrained_max_quota_buffer_size OFF (default:OFF)
# D0912 22:57:31.352457391      15 config.cc:119]                        gRPC EXPERIMENT new_hpack_huffman_decoder           ON  (default:ON)
# D0912 22:57:31.352459634      15 config.cc:119]                        gRPC EXPERIMENT event_engine_client                 OFF (default:OFF)
# D0912 22:57:31.352461914      15 config.cc:119]                        gRPC EXPERIMENT monitoring_experiment               ON  (default:ON)
# D0912 22:57:31.352464214      15 config.cc:119]                        gRPC EXPERIMENT promise_based_client_call           OFF (default:OFF)
# D0912 22:57:31.352466344      15 config.cc:119]                        gRPC EXPERIMENT free_large_allocator                OFF (default:OFF)
# D0912 22:57:31.352468501      15 config.cc:119]                        gRPC EXPERIMENT promise_based_server_call           OFF (default:OFF)
# D0912 22:57:31.352470673      15 config.cc:119]                        gRPC EXPERIMENT transport_supplies_client_latency   OFF (default:OFF)
# D0912 22:57:31.352472824      15 config.cc:119]                        gRPC EXPERIMENT event_engine_listener               OFF (default:OFF)
# I0912 22:57:31.352742529      15 ev_epoll1_linux.cc:122]               grpc epoll fd: 63
# D0912 22:57:31.352756201      15 ev_posix.cc:144]                      Using polling engine: epoll1
# D0912 22:57:31.352798575      15 dns_resolver_ares.cc:822]             Using ares dns resolver
# D0912 22:57:31.353261402      15 lb_policy_registry.cc:46]             registering LB policy factory for "priority_experimental"
# D0912 22:57:31.353275586      15 lb_policy_registry.cc:46]             registering LB policy factory for "outlier_detection_experimental"
# D0912 22:57:31.353286248      15 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_target_experimental"
# D0912 22:57:31.353296334      15 lb_policy_registry.cc:46]             registering LB policy factory for "pick_first"
# D0912 22:57:31.353299758      15 lb_policy_registry.cc:46]             registering LB policy factory for "round_robin"
# D0912 22:57:31.353303033      15 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_round_robin_experimental"
# D0912 22:57:31.353311996      15 lb_policy_registry.cc:46]             registering LB policy factory for "ring_hash_experimental"
# D0912 22:57:31.353340963      15 lb_policy_registry.cc:46]             registering LB policy factory for "grpclb"
# D0912 22:57:31.353389816      15 lb_policy_registry.cc:46]             registering LB policy factory for "rls_experimental"
# D0912 22:57:31.353409248      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_manager_experimental"
# D0912 22:57:31.353412998      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_impl_experimental"
# D0912 22:57:31.353416363      15 lb_policy_registry.cc:46]             registering LB policy factory for "cds_experimental"
# D0912 22:57:31.353424809      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_resolver_experimental"
# D0912 22:57:31.353428234      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_override_host_experimental"
# D0912 22:57:31.353432006      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_wrr_locality_experimental"
# D0912 22:57:31.353436596      15 certificate_provider_registry.cc:35]  registering certificate provider factory for "file_watcher"
# I0912 22:57:31.356928624      15 socket_utils_common_posix.cc:408]     Disabling AF_INET6 sockets because ::1 is not available.
# I0912 22:57:31.371492367     392 socket_utils_common_posix.cc:337]     TCP_USER_TIMEOUT is available. TCP_USER_TIMEOUT will be used thereafter
# E0912 22:57:47.380439596      15 oauth2_credentials.cc:236]            oauth_fetch: UNKNOWN:C-ares status is not ARES_SUCCESS qtype=A name=metadata.google.internal. is_balancer=0: Timeout while contacting DNS servers {created_time:"2024-09-12T22:57:47.380416289+00:00", grpc_status:2}
# Using TensorFlow backend

# %% [markdown]
# ### Accelerator <a id='2'></a>

# %%
 try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
    strategy = tf.distribute.TPUStrategy(tpu)
except ValueError:
    print("TPU not activated")
    strategy = tf.distribute.MirroredStrategy()
    
print("replicas:", strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: local
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# replicas: 8

# %% [markdown]
# ### Load Data <a id='3'></a>

# %%
df_train = pd.read_csv('/kaggle/input/contradictory-my-dear-watson/train.csv')
print(f"Train dataset size: {df_train.shape}")
# Out:
# Train dataset size: (12120, 6)

# %% [markdown]
# ### Data Exploring <a id='4'></a>

# %%
df_train.head(3)
# Out:
#            id                                            premise  \
# 0  5130fd2cb5  and these comments were considered in formulat...
# 1  5b72532a0b  These are issues that we wrestle with in pract...
# 2  3931fbe82a  Des petites choses comme celles-là font une di...
#
#                                           hypothesis lang_abv language  label
# 0  The rules developed in the interim were put to...       en  English      0
# 1  Practice groups are not permitted to work on t...       en  English      2
# 2              J'essayais d'accomplir quelque chose.       fr   French      0

# %% [markdown]
# The NLI model will assign labels of 0, 1, or 2 (corresponding to entailment, neutral, and contradiction) to pairs of premises and hypotheses.

# %% [markdown]
# | <span style="color:cornflowerblue">Label</span> | <span style="color:cornflowerblue">Description</span>       |
# |---------------------------------------|---------------------------------------------------|
# | 0                                     | Entailment                                        |
# | 1                                     | Neutral                                           |
# | 2                                     | Contradiction                                     |

# %%
labels_map = {0: 'Entailment', 1: 'Neutral', 2: 'Contradiction'}
label_counts = df_train['label'].map(labels_map).value_counts()

def func(pct, allvals):
    absolute = int(pct/100.*sum(allvals))
    return f"{absolute} ({pct:.1f}%)"

plt.figure(figsize=(8, 4))
wedges, texts, autotexts = plt.pie(label_counts,autopct=lambda pct: func(pct, label_counts),labels=[None]*len(label_counts),colors=plt.cm.Paired.colors)
plt.legend(wedges, label_counts.index, title="Labels", loc="center left", bbox_to_anchor=(1, 0.5))
plt.title("Distribution of Natural Language Inference Labels")
display()

# %%
df_train['language'].value_counts()
# Out:
# language
# English       6870
# Chinese        411
# Arabic         401
# French         390
# Swahili        385
# Urdu           381
# Vietnamese     379
# Russian        376
# Hindi          374
# Greek          372
# Thai           371
# Spanish        366
# Turkish        351
# German         351
# Bulgarian      342
# Name: count, dtype: int64

# %%
train2 = df_train.copy()

def word_count(text):
    return len(text.split())

def char_count(text):
    return len(text)

train2['premise_word_count'] = train2['premise'].apply(word_count)
train2['premise_char_count'] = train2['premise'].apply(char_count)
train2['hypothesis_word_count'] = train2['hypothesis'].apply(word_count)
train2['hypothesis_char_count'] = train2['hypothesis'].apply(char_count)

def describe_column(column):
    stats = {
        'mean': int(column.mean()),
        'max': int(column.max()),
        'min': int(column.min())
    }
    return stats

premise_word_stats = describe_column(train2['premise_word_count'])
premise_char_stats = describe_column(train2['premise_char_count'])
hypothesis_word_stats = describe_column(train2['hypothesis_word_count'])
hypothesis_char_stats = describe_column(train2['hypothesis_char_count'])

stats = {
    'Premise Words': premise_word_stats,
    'Hypothesis Words': hypothesis_word_stats,
    'Premise Characters': premise_char_stats,
    'Hypothesis Characters': hypothesis_char_stats}

stats = pd.DataFrame(stats).T
stats
# Out:
#                        mean  max  min
# Premise Words            17  196    1
# Hypothesis Words          9   46    1
# Premise Characters      107  967    4
# Hypothesis Characters    53  276    4

# %%
stopwords = set(STOPWORDS)

text_hypothesis = ' '.join(df_train['hypothesis'].astype(str))
wordcloud_hypothesis = WordCloud(width=800, height=400, background_color='white', stopwords=stopwords).generate(text_hypothesis)
text_premises = ' '.join(df_train['premise'].astype(str))
wordcloud_premises = WordCloud(width=800, height=400, background_color='white', stopwords=stopwords).generate(text_premises)

plt.figure(figsize=(15, 8))

plt.subplot(1, 2, 1)
plt.imshow(wordcloud_hypothesis, interpolation='bilinear')
plt.title('Word Cloud - Hypothesis (without stopwords)')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(wordcloud_premises, interpolation='bilinear')
plt.title('Word Cloud - Premise (without stopwords)')
plt.axis('off')

display()

# %% [markdown]
# ### Data Preprocessing <a id='5'></a>

# %%
VALIDATION_SPLIT = 0.3
TRAIN_SIZE = int(df_train.shape[0]*(1-VALIDATION_SPLIT))
BATCH_SIZE = 16 * strategy.num_replicas_in_sync

# %%
def split_labels(x, y):
    return (x[0], x[1]), y

training_dataset = (
    tf.data.Dataset.from_tensor_slices(
        (
            df_train[['premise','hypothesis']].values,
            keras.utils.to_categorical(df_train['label'], num_classes=3)
        )
    )
)

train_dataset = training_dataset.take(TRAIN_SIZE)
val_dataset = training_dataset.skip(TRAIN_SIZE)

train_preprocessed = train_dataset.map(split_labels, tf.data.AUTOTUNE).batch(BATCH_SIZE, drop_remainder=True).cache().prefetch(tf.data.AUTOTUNE)
val_preprocessed = val_dataset.map(split_labels, tf.data.AUTOTUNE).batch(BATCH_SIZE, drop_remainder=True).cache().prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### BERT Base Multi <a id='6'></a>

# %%
with strategy.scope():
    classifier = keras_nlp.models.BertClassifier.from_preset("bert_base_multi", num_classes=3)
    classifier.compile(optimizer=keras.optimizers.Adam(1e-5*strategy.num_replicas_in_sync),
                       loss=keras.losses.CategoricalCrossentropy(from_logits=True),
                       metrics=['accuracy'])
    classifier.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-nlp/models/bert_base_multi/v1/vocab.txt
# 995526/995526 [==============================] - 1s 1us/step
# Downloading data from https://storage.googleapis.com/keras-nlp/models/bert_base_multi/v1/model.h5
# 711647480/711647480 [==============================] - 23s 0us/step
# Preprocessor: "bert_preprocessor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Tokenizer (type)                                   ┃                                             Vocab # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ bert_tokenizer (BertTokenizer)                     │                                             119,547 │
# └────────────────────────────────────────────────────┴─────────────────────────────────────────────────────┘
# Model: "bert_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                                  ┃ Output Shape                           ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ padding_mask (InputLayer)                     │ (None, None)                           │               0 │
# ├───────────────────────────────────────────────┼────────────────────────────────────────┼─────────────────┤
# │ segment_ids (InputLayer)                      │ (None, None)                           │               0 │
# ├───────────────────────────────────────────────┼────────────────────────────────────────┼─────────────────┤
# │ token_ids (InputLayer)                        │ (None, None)                           │               0 │
# ├───────────────────────────────────────────────┼────────────────────────────────────────┼─────────────────┤
# │ bert_backbone (BertBackbone)                  │ {sequence_output: (None, None, 768),   │     177,853,440 │
# │                                               │ pooled_output: (None, 768)}            │                 │
# ├───────────────────────────────────────────────┼────────────────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                             │ (None, 768)                            │               0 │
# ├───────────────────────────────────────────────┼────────────────────────────────────────┼─────────────────┤
# │ logits (Dense)                                │ (None, 3)                              │           2,307 │
# └───────────────────────────────────────────────┴────────────────────────────────────────┴─────────────────┘
#  Total params: 177,855,747 (678.47 MB)
#  Trainable params: 177,855,747 (678.47 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
EPOCHS=7
history = classifier.fit(train_preprocessed,
                         epochs=EPOCHS,
                         validation_data=val_preprocessed)
# Out:
# Epoch 1/7
# 2024-09-12 23:00:51.859298: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 2024-09-12 23:00:52.713725: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 66/66 [==============================] - ETA: 0s - loss: 0.9720 - accuracy: 0.5179
# 2024-09-12 23:02:14.838138: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 2024-09-12 23:02:15.103254: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp.
# 66/66 [==============================] - 122s 663ms/step - loss: 0.9720 - accuracy: 0.5179 - val_loss: 0.8519 - val_accuracy: 0.6189
# Epoch 2/7
# 66/66 [==============================] - 34s 511ms/step - loss: 0.7527 - accuracy: 0.6656 - val_loss: 0.8394 - val_accuracy: 0.6434
# Epoch 3/7
# 66/66 [==============================] - 33s 498ms/step - loss: 0.5733 - accuracy: 0.7629 - val_loss: 0.9297 - val_accuracy: 0.6122
# Epoch 4/7
# 66/66 [==============================] - 32s 485ms/step - loss: 0.4381 - accuracy: 0.8314 - val_loss: 1.0896 - val_accuracy: 0.6046
# Epoch 5/7
# 66/66 [==============================] - 32s 486ms/step - loss: 0.3210 - accuracy: 0.8789 - val_loss: 1.1141 - val_accuracy: 0.6412
# Epoch 6/7
# 66/66 [==============================] - 33s 508ms/step - loss: 0.2293 - accuracy: 0.9170 - val_loss: 1.4341 - val_accuracy: 0.6261
# Epoch 7/7
# 66/66 [==============================] - 32s 487ms/step - loss: 0.1729 - accuracy: 0.9405 - val_loss: 1.4645 - val_accuracy: 0.6239

# %%
history_df = pd.DataFrame(history.history)
history_df.index = range(1, len(history_df) + 1)

# %%
colors = plt.cm.Paired.colors

plt.figure(figsize=(12, 6))
plt.plot(history_df.index, history_df['accuracy'], label='Training Accuracy', color=colors[1], marker='o')
plt.plot(history_df.index, history_df['val_accuracy'], label='Validation Accuracy', color=colors[3], marker='s')
plt.title('Accuracy over epochs', fontsize=16)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0, 1)

for i in history_df.index:
    plt.annotate(f'{history_df.loc[i, "accuracy"]:.3f}', (i, history_df.loc[i, "accuracy"]), 
                 textcoords="offset points", xytext=(0, 8), ha='center', fontsize=10)

for i in history_df.index:
    plt.annotate(f'{history_df.loc[i, "val_accuracy"]:.3f}', (i, history_df.loc[i, "val_accuracy"]), 
                 textcoords="offset points", xytext=(0, 8), ha='center', fontsize=10)

plt.tight_layout()
plt.legend()
display()

# %%
colors = plt.cm.Paired.colors

plt.figure(figsize=(12, 6))
plt.plot(history_df.index, history_df['loss'], label='Training Loss', color=colors[1], marker='o')
plt.plot(history_df.index, history_df['val_loss'], label='Validation Loss', color=colors[3], marker='s')
plt.title('Loss over epochs', fontsize=16)
plt.xlabel('Epochs')
plt.ylabel('Loss')

for i in history_df.index:
    plt.annotate(f'{history_df.loc[i, "loss"]:.3f}', (i, history_df.loc[i, "loss"]), 
                 textcoords="offset points", xytext=(0, 8), ha='center', fontsize=10)

for i in history_df.index:
    plt.annotate(f'{history_df.loc[i, "val_loss"]:.3f}', (i, history_df.loc[i, "val_loss"]), 
                 textcoords="offset points", xytext=(0, 8), ha='center', fontsize=10)

plt.tight_layout()
plt.legend()
display()
